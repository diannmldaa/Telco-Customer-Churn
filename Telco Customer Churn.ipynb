# %% [markdown]
# ## Use Case Summary
#
# ### Objective Statement
#
# <!-- - Get Insight about ratio about gender has churn or not -->
# <!-- - __Get an insight about how much influence the Contract has  on customer churn__  -->
# <!-- - Get an insight about how much influence the Partner has  on customer churn -->
# <!-- - Get an insight about how much influence the Internet Services on customer churn -->
#
# - Get an insight about the influence of gender on customer churn.
# - Describe customer satisfaction seen from the length of their contract that affects customer churn.
# - Get an insight about how much influence the Senior Citizen on customer churn
# - Get an insight about how much influence Dependents on customer churn
# - Get an insight about how much influence Paperless billing on customer churn
# - Gain knowledge of how important partners influence customer churn
# - Gain knowledge of how important the type of InternetService to influence customer churn
#
# - Get an insight about how much influence the Phone Services on customer churn
# <!-- - Gain insight into the contracts that customers frequently choose -->
# - Get an insight about how much influence the Online Security on customer churn
# - Get an insight about how much influence the Online Backup on customer churn
# - Get an insight about how much influence the Device Protection on customer churn
# - Get an insight about how much influence the Tech Support on customer churn
# - Get an insight about how much influence the StreamingTV on customer churn
# - Get an insight about how much influence the Streaming Movie on customer churn
# - Get an insight about how much influence the payment method on Customer Churn
# <!-- - Make marketing strategy which service need to be improved based on churn analysis -->
# - Create machine learning models to predict customers who will churn
#
# ### Challenges
#
# - The data have a lot missing value
# - There is data that has an inappropriate data type
# - The data scale is not all the same
#
# ### Methodology / Analytic Technique
#
# - Descriptive analysis
# - Graph analysis
# - Machine learning model (classification)
#
# ## Business Benefit
#
# - Help marketing strategies to improve products or services so that customer churn can be reduced.
# - Help find out which aspects need to be developed to reduce customer churn.
#
# ### Expected Outcome
# <!-- - Get to know how much influence the Internet Services on customer churn -->
# <!-- - Get to know about ratio about gender has churn or not
# - Get to know how much influence the Contract has  on customer churn
# - Get to know how much influence the Partner has  on customer churn -->
# <!-- - Get insight into the contracts that customers frequently choose -->
# - Knowing the influence of gender on customer churn.
# - Knowing customer satisfaction seen from the length of their contract that affects customer churn.
# - Get to know how much influence the Senior Citizen on customer churn.
# - Get to know how much influence the Dependents on customer churn.
# - Get to know how much influence the Paperless Billing on customer churn.
# - Knowing how important partners influence customer churn.
# - Knowing how important the type of InternetService to influence customer churn
# - Get to know how much influence the Phone Services on customer churn.
# - Get to know how much influence the Online Security on customer churn.
# - Get to know how much influence the Online Backup on customer churn.
# - Get to know how much influence the Device Protection on customer churn.
# - Get to know how much influence the Tech Support on customer churn.
# - Get to know how much influence the StreamingTV on customer churn.
# - Get to know how much influence the Streaming Movie on customer churn.
# - Gain an insight about how services affect the customer churn.
#
# - Get to know how much influence the payment method on Customer Churn
# <!-- - Making marketing strategy which service need to be improved based on churn analysis -->
# - Making machine learning models to predict customers who will churn

# %% [markdown]
# ## Business Understanding
#
# <!-- “Customer Churn” refers to the loss of customers. That is, if a customer or a client stops taking services from a company, it is said that he/she has churned.
#
# Churn is intimately connected to a company’s performance. The more one learns about buyers’ behavior, the more money one can make. Analyzing customer churn also aids in finding and improving the shortcomings of services provided by the company.
#
# The churn rate based on SeniorCitizen show that churn rate is low to non senior citizen customer, most of those who leave telco service is the non senior citizen (younger citizen).
#
# The churn rate based on customer InternetService show that churn rate is high in the fiber optic category, and second is DSL.
#
# Churn rate based on contract customer, 'monthly-to-month' contract customers have high impact in data telco. -->
#
# **Customer Churn** refers to the loss of customers. Churn is intimately connected to a company’s performance. The more one learns about buyers’ behavior, the more money one can make. Analyzing customer churn also aids in finding and improving the shortcomings of services provided by the company. Customer churn rate must to be reduce so that the company's income increases
#
# this case has some business question using the data:
# - How gender affects the customer churn ?
# - How customer satisfaction seen from the length of their contract that affect customer churn ?
# - How important partners influences customer churn ?
# - How important the type of InternetService to influence customer churn ?
# <!-- - what is the biggest thing that causes of customer churn? -->
# - how many percentage is predict to be churn?

# %% [markdown]
# ## Data Understanding
#
# **Source Data**
# - Sorce Data: https://github.com/Yesaya03/Machine-Learning-Regression-and-Timeseries/blob/main/data_telco.csv
# - 7043 rows
# - 21 columns
#
# **Data Dictionary**
#
# Services that each customer has signed
# -	OnlineSecurity: customer has online security or not (Yes, No, No internet service)
# -	OnlineBackup: customer has online backup or not (Yes, No, No internet service)
# -	PhoneService: customer has a phone service or not (Yes, No)
# -	MultipleLines: customer has multiple lines or not (Yes, No, No phone service)
# -	InternetService: Customer’s internet service provider (DSL, Fiber optic, No)
# -	DeviceProtection: customer has device protection or not (Yes, No, No internet service)
# -	TechSupport: customer has tech support or not (Yes, No, No internet service)
# -	StreamingTV:customer has streaming TV or not (Yes, No, No internet service)
# -	StreamingMovies: customer has streaming movies or not (Yes, No, No internet service)
#
#
# Information account for customer
# -	tenure : Number of months the customer has stayed with the company
# -	Contract: The contract term of the customer (Month-to-month, One year, Two year)
# -	PaymentMethod: The customer’s payment method (Electronic check, Mailed check, Bank transfer (automatic), Credit card (automatic))
# -	PaperlessBilling: customer has paperless billing or not (Yes, No)
# -	MonthlyCharges: The amount charged to the customer monthly
# -	TotalCharges: The total amount charged to the customer
#
# Demographic info
# -	gender : male or a female (Male, Female)
# -	Partner : customer has a partner or not (Yes, No)
# -	Dependents : customer has dependents or not (Yes, No)
# - customerID : Customer ID
# -	SeniorCitizen :customer is a senior citizen or not (1, 0)
#
#
# labels for classification
# -	Churn :customer churned or not (Yes or No)

# %% [markdown]
# ## Data Preparation
# - Python version : 3.9.12
# - Packages Version : Pandas, numpy, matplotlib, seaborn, and sklearn

# %%
# import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import train_test_split
from sklearn.ensemble import ExtraTreesClassifier

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score, accuracy_score, precision_score, recall_score, confusion_matrix, roc_curve, auc, log_loss
#from imblearn.over_sampling import SMOTE
from imblearn import under_sampling, over_sampling

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data Profiling

# %%
# Load and Preview Dataset
df = pd.read_csv('data_telco.csv')
df.head()
# Out:
#    customerID gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG    NaN            NaN     NaN        NaN       1           No
# 1  5575-GNVDE    NaN            NaN     NaN        NaN      34          Yes
# 2  3668-QPYBK    NaN            NaN     NaN        NaN       2          Yes
# 3  7795-CFOCW    NaN            NaN     NaN        NaN      45           No
# 4  9237-HQITU    NaN            NaN     NaN        NaN       2          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0           NaN             NaN            NaN  ...              NaN
# 1           NaN             NaN            NaN  ...              NaN
# 2           NaN             NaN            NaN  ...              NaN
# 3           NaN             NaN            NaN  ...              NaN
# 4           NaN             NaN            NaN  ...              NaN
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            6034 non-null   object
#  2   SeniorCitizen     6034 non-null   float64
#  3   Partner           6034 non-null   object
#  4   Dependents        6034 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     6034 non-null   object
#  8   InternetService   6034 non-null   object
#  9   OnlineSecurity    6034 non-null   object
#  10  OnlineBackup      6034 non-null   object
#  11  DeviceProtection  6034 non-null   object
#  12  TechSupport       6034 non-null   object
#  13  StreamingTV       6034 non-null   object
#  14  StreamingMovies   6034 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# customerID             0
# gender              1009
# SeniorCitizen       1009
# Partner             1009
# Dependents          1009
# tenure                 0
# PhoneService           0
# MultipleLines       1009
# InternetService     1009
# OnlineSecurity      1009
# OnlineBackup        1009
# DeviceProtection    1009
# TechSupport         1009
# StreamingTV         1009
# StreamingMovies     1009
# Contract               0
# PaperlessBilling       0
# PaymentMethod          0
# MonthlyCharges         0
# TotalCharges           0
# Churn                  0
# dtype: int64

# %% [markdown]
# ## Data Cleansing

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    6034.000000  7043.000000     7043.000000
# mean        0.161916    32.371149       64.761692
# std         0.368404    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
col = ['gender', 'SeniorCitizen', 'Dependents', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Partner']
for i in range(len(col)):
    df[col[i]] = df[col[i]].fillna("unknown")

df
# Out:
#       customerID   gender SeniorCitizen  Partner Dependents  tenure  \
# 0     7590-VHVEG  unknown       unknown  unknown    unknown       1
# 1     5575-GNVDE  unknown       unknown  unknown    unknown      34
# 2     3668-QPYBK  unknown       unknown  unknown    unknown       2
# 3     7795-CFOCW  unknown       unknown  unknown    unknown      45
# 4     9237-HQITU  unknown       unknown  unknown    unknown       2
# ...          ...      ...           ...      ...        ...     ...
# 7038  6840-RESVB     Male           0.0      Yes        Yes      24
# 7039  2234-XADUH   Female           0.0      Yes        Yes      72
# 7040  4801-JZAZL   Female           0.0      Yes        Yes      11
# 7041  8361-LTMKD     Male           1.0      Yes         No       4
# 7042  3186-AJIEK     Male           0.0       No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No           unknown         unknown        unknown  ...
# ...

# %%
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# change data types
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Data Numeric

# %%
features = ['tenure', 'MonthlyCharges', 'TotalCharges']

plt.figure(figsize=(15, 8))
for i in range(0, len(features)):
    plt.subplot(2, 3, i+1)
    sns.distplot(x=df[features[i]], color='salmon')
    plt.xlabel(features[i]);

# %% [markdown]
# - `tenure`, `MonthlyCharges`, and `TotalCharges` have a non-normal distribution, especially on the variable `TotalCharges` the distribution graph looks very skewed to the right/positive skew.
# - The graph of the variable `tenure` shows that the data distribution is uneven and tends to be high when tenure is very low or very high.
# - In the `MonthlyCharges` graph it can be seen that the distribution graph is not normal and it can be seen that the low MonthlyCharges has quite a lot of frequency.
# - `TotalCharges` distribution graph is not normal (positive skew) so it can be seen that telecommunication data is dominated by customers with low TotalCharges

# %% [markdown]
# ### Data Categorical

# %%
col = ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 
       'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod']

flatui = ["#2b2d42", "#8d99ae", 'salmon', '#c9ada7']
sns.set_palette(flatui)

plt.figure(figsize=(18, 15))
for i in range(0, len(col)):
    plt.subplot(4, 4, i+1)
    sns.countplot(data=df, x=df[col[i]], palette=sns.color_palette());

# %% [markdown]
# - `gender`, `SeniorCitizen`, `Partner`, `Dependents`, `MultipleLines`, `InternetService`, `OnlineSecurity`, `OnlineBackup`, `DeviceProtection`, `TechSupport`, `StreamingTV`, `StreamingMovie` , `Contract`, and `PaymentMethod` variables have missing values ​​so there is 'unknown' data
# - `PhoneService` and `PaperlessBilling` variables there is no missing value so there is no 'unknown' data
#
#
# - Based on the `gender` variable, it can be seen that the number of male and female customers in the telco data tends to be balanced and not too dominant between one another.
# - Based on the `SeniorCitizen` variable, it can be seen that most telco customers are not from Senior Citizen
# - Based on the `Partner` variable, it can be seen that the number of customers who have partners and do not tend to be balanced so that they are not too dominant between one another.
# - Based on the `Dependents` variable, it can be seen that
# - Based on the `Partner` variable, it can be seen that telco customers are dominated by customer dependents
# - Based on the `PhoneService` variable, it can be seen that telco customers are dominated by customers who use Phone Service
# - Based on the variable `MultipleLines`, it can be seen that telco customers are dominated by customers who do not have multiple lines
# - Based on the `InternetService` variable, it can be seen that telco customers are dominated by customers who use Fiber Internet Service
# - Based on the `OnlineSecurity` variable, it can be seen that telco customers are dominated by customers who do not use Online Security services
# - Based on the `OnlineBackup` variable, it can be seen that telco customers are dominated by customers who do not use the Online Backup service
# - Based on the `DeviceProtection` variable, it can be seen that telco customers are dominated by customers who do not use Device Protection services
# - Based on the `TechSupport` variable, it can be seen that telco customers are dominated by customers who do not use Tech Support services
# - Based on the `StreamingTV` variable, it can be seen that telco customers are dominated by customers who do not stream TV
# - Based on the `StreamingMovies` variable, it can be seen that telco customers are dominated by customers who do not stream movies
# - Based on the `Contract` variable, it can be seen that the most contracts executed by telco customers are Month-to-Month contracts.
# - Based on the `PaperlessBilling` variable, it can be seen that more customers use Paperless Billing than those who do not.
# - Based on the `PaymentMethod` variable, it can be seen that the most widely used payment method by telco customers is through Electronic check

# %% [markdown]
# ### Data Target

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
plt.figure(figsize=(6,4)) 
df['Churn'].value_counts().plot(kind='bar', color='salmon')
plt.title('Churn and Not Churn')

plt.text(0, 5300, '73,46%', ha='center', va='center', fontsize=10)
plt.text(1, 2000, '26,54%', ha='center', va='center', fontsize=10);

# %%
data = df['Churn'].value_counts()
labels = ['Not Churn', 'Churn']

#define Seaborn color palette to use
colors = sns.color_palette(['salmon', "#2b2d42"])[0:5]

#create pie chart
plt.pie(data, labels = labels, colors = colors, autopct='%.0f%%')
plt.show();

# %% [markdown]
# Churn bar plot/pie chart above show that most of telco customer are not churn, customers who churn less than half

# %%
df['SeniorCitizen'].value_counts()
# Out:
# 0.0        5057
# unknown    1009
# 1.0         977
# Name: SeniorCitizen, dtype: int64

# %%
flatui = ["#8d99ae", "#2b2d42", 'salmon']
sns.set_palette(flatui)

plt.figure(figsize=(6,4)) 
graph = sns.countplot(x='SeniorCitizen', data=df,palette=sns.color_palette())

plt.text(0, 1170, '14,33%', ha='center', va='center', fontsize=10)
plt.text(1, 1120, '13,87%', ha='center', va='center', fontsize=10)
plt.text(2, 5160, '71,80%', ha='center', va='center', fontsize=10);

# %%
flatui = ["#8d99ae", "#2b2d42", 'salmon']
sns.set_palette(flatui)

plt.figure(figsize=(8,6)) 
graph = sns.countplot(x='Churn', data=df, hue='SeniorCitizen', palette=sns.color_palette())

plt.text(-0.28, 820, '10,62%', ha='center', va='center', fontsize=12) 
plt.text(0, 660, '8,04%', ha='center', va='center', fontsize=12)
plt.text(0.25, 3950, '54,81%', ha='center', va='center', fontsize=12) 
plt.text(0.75, 350, '3,71%', ha='center', va='center', fontsize=12)
plt.text(1, 500, '5,84%', ha='center', va='center', fontsize=12)
plt.text(1.27, 1270, '17,00%', ha='center', va='center', fontsize=12);

# %%
group_k = df[['customerID', 'SeniorCitizen', 'Churn']].groupby(['SeniorCitizen', 'Churn'])['customerID'].nunique()
group_k = group_k.reset_index()
group_k.columns = ['SeniorCitizen', 'Churn', 'jumlahCustomer']
group_merge_k = group_k
group_merge_k['Persentase'] = round((group_merge_k['jumlahCustomer']/7043*100), 2)
group_merge_k
# Out:
#   SeniorCitizen Churn  jumlahCustomer  Persentase
# 0           0.0    No            3860       54.81
# 1           0.0   Yes            1197       17.00
# 2           1.0    No             566        8.04
# 3           1.0   Yes             411        5.84
# 4       unknown    No             748       10.62
# 5       unknown   Yes             261        3.71

# %% [markdown]
# Based on the senior citizen category, we can see that most telco customers is non senior citizen in front of the percentage 71.80% the level of customer  churn of senior citizens is also low, the largest customer churn is from the non-senior citizen class with a percentage of 17%

# %%
df['Dependents'].value_counts()
# Out:
# No         4238
# Yes        1796
# unknown    1009
# Name: Dependents, dtype: int64

# %%
flatui = ["#8d99ae", "#2b2d42", 'salmon']
sns.set_palette(flatui)

plt.figure(figsize=(6,4)) 
graph = sns.countplot(x='Dependents', data=df,palette=sns.color_palette())

plt.text(0, 1170, '14,33%', ha='center', va='center', fontsize=10)
plt.text(1, 4350, '60,17%', ha='center', va='center', fontsize=10)
plt.text(2, 1940, '25,50%', ha='center', va='center', fontsize=10);

# %%
flatui = ["#8d99ae", "#2b2d42", 'salmon']
sns.set_palette(flatui)

plt.figure(figsize=(8,6)) 
graph = sns.countplot(x='Churn', data=df, hue='Dependents', palette=sns.color_palette())

plt.text(-0.28, 820, '10,62%', ha='center', va='center', fontsize=12) 
plt.text(0, 2980, '41,35%', ha='center', va='center', fontsize=12)
plt.text(0.25, 1590, '21,50%', ha='center', va='center', fontsize=12) 
plt.text(0.75, 350, '3,71%', ha='center', va='center', fontsize=12)
plt.text(1, 1400, '18,83%', ha='center', va='center', fontsize=12)
plt.text(1.27, 350, '4,00%', ha='center', va='center', fontsize=12);

# %%
group_l = df[['customerID', 'Dependents', 'Churn']].groupby(['Dependents', 'Churn'])['customerID'].nunique()
group_l = group_l.reset_index()
group_l.columns = ['Dependents', 'Churn', 'jumlahCustomer']
group_merge_l = group_l
group_merge_l['Persentase'] = round((group_merge_l['jumlahCustomer']/7043*100), 2)
group_merge_l
# Out:
#   Dependents Churn  jumlahCustomer  Persentase
# 0         No    No            2912       41.35
# 1         No   Yes            1326       18.83
# 2        Yes    No            1514       21.50
# 3        Yes   Yes             282        4.00
# 4    unknown    No             748       10.62
# 5    unknown   Yes             261        3.71

# %% [markdown]
# Telco customers mostly do not have dependants with a percentage of 60.17% compared to customers which has a dependent that is equal to 25.50%. Customers who churn based on the most dependents are customers who do not have dependents
# with a percentage of 18.83%, even so customers who still stick with telco services still quite a lot with a total of 73.47%

# %%
df['PaperlessBilling'].value_counts()
# Out:
# Yes    4171
# No     2872
# Name: PaperlessBilling, dtype: int64

# %%
flatui = ["#8d99ae", "#2b2d42", 'salmon']
sns.set_palette(flatui)

plt.figure(figsize=(6,4)) 
graph = sns.countplot(x='PaperlessBilling', data=df,palette=sns.color_palette())

plt.text(0, 4240, '59,22%', ha='center', va='center', fontsize=10)
plt.text(1, 2970, '40,78%', ha='center', va='center', fontsize=10);

# %%
flatui = ["#8d99ae", "#2b2d42", 'salmon']
sns.set_palette(flatui)

plt.figure(figsize=(8,6)) 
graph = sns.countplot(x='Churn', data=df, hue='PaperlessBilling', palette=sns.color_palette())

plt.text(-0.17, 2840, '39,34%', ha='center', va='center', fontsize=12)
plt.text(0.19, 2500, '34,12%', ha='center', va='center', fontsize=12)
plt.text(0.79, 1480, '19,88%', ha='center', va='center', fontsize=12)
plt.text(1.19, 540, '6,66%', ha='center', va='center', fontsize=12);

# %%
group_m = df[['customerID', 'PaperlessBilling', 'Churn']].groupby(['PaperlessBilling', 'Churn'])['customerID'].nunique()
group_m = group_m.reset_index()
group_m.columns = ['PaperlessBilling', 'Churn', 'jumlahCustomer']
group_merge_m = group_m
group_merge_m['Persentase'] = round((group_merge_m['jumlahCustomer']/7043*100), 2)
group_merge_m
# Out:
#   PaperlessBilling Churn  jumlahCustomer  Persentase
# 0               No    No            2403       34.12
# 1               No   Yes             469        6.66
# 2              Yes    No            2771       39.34
# 3              Yes   Yes            1400       19.88

# %% [markdown]
# Telco customers based on paperless billing are the most customers who using paperless billing with a presentation of 59.22%, while customers who do not use paperless billing in the amount of 40.78%, the customers who churn the most are customers who use paperless billing with a percentage of 19.88%

# %%
df['gender'].value_counts()
# Out:
# Male       3041
# Female     2993
# unknown    1009
# Name: gender, dtype: int64

# %%
flatui = ["#8d99ae", "#2b2d42", 'salmon']
sns.set_palette(flatui)

plt.figure(figsize=(6,4)) 
graph = sns.countplot(x='gender', data=df,palette=sns.color_palette())

plt.text(0, 1100, '14,33%', ha='center', va='center', fontsize=10)
plt.text(1, 3120, '43,18%', ha='center', va='center', fontsize=10)
plt.text(2, 3080, '42,49%', ha='center', va='center', fontsize=10);

# %%
flatui = ["#8d99ae", "#2b2d42", 'salmon']
sns.set_palette(flatui)

plt.figure(figsize=(8,6)) 
graph = sns.countplot(x='Churn', data=df, hue='gender', palette=sns.color_palette())

plt.text(-0.28, 800, '10,62%', ha='center', va='center', fontsize=12) 
plt.text(0, 2300, '31,79%', ha='center', va='center', fontsize=12)
plt.text(0.25, 2250, '31,05%', ha='center', va='center', fontsize=12) 
plt.text(0.75, 300, '3,71%', ha='center', va='center', fontsize=12)
plt.text(1, 860, '11,39%', ha='center', va='center', fontsize=12)
plt.text(1.27, 860, '11,44%', ha='center', va='center', fontsize=12);

# %%
group_a = df[['customerID', 'gender', 'Churn']].groupby(['gender', 'Churn'])['customerID'].nunique()
group_a = group_a.reset_index()
group_a.columns = ['gender', 'Churn', 'jumlahCustomer']
group_merge_a = group_a
group_merge_a['Persentase'] = round((group_merge_a['jumlahCustomer']/7043*100), 2)
group_merge_a
# Out:
#     gender Churn  jumlahCustomer  Persentase
# 0   Female    No            2187       31.05
# 1   Female   Yes             806       11.44
# 2     Male    No            2239       31.79
# 3     Male   Yes             802       11.39
# 4  unknown    No             748       10.62
# 5  unknown   Yes             261        3.71

# %% [markdown]
# from 7043 customer there are 5147 customer who remain subscribed or about 73.46% of telco data. and based on the results of EDA gender does not have much effect on customer churn, because the percentage results show the same thing, which is in the range of 31% of the total

# %%
df['Contract'].value_counts()
# Out:
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Contract, dtype: int64

# %%
flatui = ["#8d99ae", "#2b2d42", 'salmon']
sns.set_palette(flatui)

plt.figure(figsize=(6,4)) 
graph = sns.countplot(x='Contract', data=df,palette=sns.color_palette())

plt.text(0, 3950, '55,02%', ha='center', va='center', fontsize=10)
plt.text(1, 1550, '24,07%', ha='center', va='center', fontsize=10)
plt.text(2, 1770, '20,91%', ha='center', va='center', fontsize=10);

# %%
flatui = ["#8d99ae", "#2b2d42", 'salmon']
sns.set_palette(flatui)

plt.figure(figsize=(8,6)) 
graph = sns.countplot(x='Churn', data=df, hue='Contract', palette=sns.color_palette())

plt.text(-0.25, 2270, '31,52%', ha='center', va='center', fontsize=12)
plt.text(0, 1350, '18,56%', ha='center', va='center', fontsize=12)
plt.text(0.25, 1700, '23,38%', ha='center', va='center', fontsize=12)
plt.text(0.75, 1700, '23,50%', ha='center', va='center', fontsize=12)
plt.text(1, 210, '2,36%', ha='center', va='center', fontsize=12)
plt.text(1.25, 90, '0,68%', ha='center', va='center', fontsize=12);

# %%
group_b = df[['customerID', 'Contract', 'Churn']].groupby(['Contract', 'Churn'])['customerID'].nunique()
group_b = group_b.reset_index()
group_b.columns = ['Contract', 'Churn', 'jumlahCustomer']
group_merge_b = group_b
group_merge_b['Persentase'] = round((group_merge_b['jumlahCustomer']/7043*100), 2)
group_merge_b
# Out:
#          Contract Churn  jumlahCustomer  Persentase
# 0  Month-to-month    No            2220       31.52
# 1  Month-to-month   Yes            1655       23.50
# 2        One year    No            1307       18.56
# 3        One year   Yes             166        2.36
# 4        Two year    No            1647       23.38
# 5        Two year   Yes              48        0.68

# %% [markdown]
# <!-- Dari sini kita tahu, bahwa customer yang melakukan churn kebanyakan yang contract atau berlanganan month to month. Sedangkan yang stabil tidak churn dan sedikit churn nya adalah contrat atau berlangganan dua tahun. Perusahaan dapat meningkatkan promo pada contrat two year. Dengan seperti itu, customer yang loyal atau setia terhadap layanan perushaan bertambah sekaligus pemasukannya bertambah. -->
#
#
#
# There are 3 points that concern us in this result:
#
# 1. Only less than 4% of customers churn where they subscribe for 1 year and 2 years, and this explains that there is no fatal cause that makes customers churn.
# 2. There is an increase in the percentage of about 4.82% between 1 year to 2 year subscriptions for customers who do not churn. that means, some loyal customers are still satisfied with the services provided by the company.
# 3. The high number of Month to Month customers who decide to churn is around 23.50%, which means that there are still many early customers who are not interested in the services provided by the company.

# %%
df['Partner'].value_counts()
# Out:
# No         3111
# Yes        2923
# unknown    1009
# Name: Partner, dtype: int64

# %%
flatui = ["#8d99ae", "#2b2d42", 'salmon']
sns.set_palette(flatui)

plt.figure(figsize=(6,4)) 
graph = sns.countplot(x='Partner', data=df,palette=sns.color_palette())

plt.text(0, 1075, '14,33%', ha='center', va='center', fontsize=10)
plt.text(1, 3020, '41,50%', ha='center', va='center', fontsize=10)
plt.text(2, 3185, '44,17%', ha='center', va='center', fontsize=10);

# %%
flatui = ["#8d99ae", "#2b2d42", 'salmon']
sns.set_palette(flatui)

plt.figure(figsize=(8,6)) 
graph = sns.countplot(x='Churn', data=df, hue='Partner', palette=sns.color_palette())

plt.text(-0.25, 800, '10,62%', ha='center', va='center', fontsize=12)
plt.text(0, 2400, '33,32%', ha='center', va='center', fontsize=12)
plt.text(0.25, 2120, '29,52%', ha='center', va='center', fontsize=12)
plt.text(0.75, 310, '3,710%', ha='center', va='center', fontsize=12)
plt.text(1, 630, '8,18%', ha='center', va='center', fontsize=12)
plt.text(1.25, 1080, '14,65%', ha='center', va='center', fontsize=12);

# %%
group_c = df[['customerID', 'Partner', 'Churn']].groupby(['Partner', 'Churn'])['customerID'].nunique()
group_c = group_c.reset_index()
group_c.columns = ['Partner', 'Churn', 'jumlahCustomer']
group_merge_c = group_c
group_merge_c['Persentase'] = round((group_merge_c['jumlahCustomer']/7043*100), 2)
group_merge_c
# Out:
#    Partner Churn  jumlahCustomer  Persentase
# 0       No    No            2079       29.52
# 1       No   Yes            1032       14.65
# 2      Yes    No            2347       33.32
# 3      Yes   Yes             576        8.18
# 4  unknown    No             748       10.62
# 5  unknown   Yes             261        3.71

# %% [markdown]
# Although the percentage of customers who do not churn and do not have partners is still high, namely 29.52%, partners are important things that can affect customer churn or not. It can be seen that there is a significant difference between churn customers who have partners and customers who do not churn without partners, namely 25.14% .
#
# From this we know, that most customers who enjoy the service are customers who do not have a partner. This is in line with the number of customers who churn, where more are customers who do not have partners. Companies can increase promotions on days associated with couples such as Valentine, to increase customers who want to use the company's services.

# %%
df['PhoneService'].value_counts()
# Out:
# Yes    6361
# No      682
# Name: PhoneService, dtype: int64

# %%
flatui = ["#8d99ae", "#2b2d42", 'salmon']
sns.set_palette(flatui)

plt.figure(figsize=(6,4)) 
graph = sns.countplot(x='PhoneService', data=df,palette=sns.color_palette())

plt.text(0, 820, '9,68%', ha='center', va='center', fontsize=10)
plt.text(1, 6490, '90,32%', ha='center', va='center', fontsize=10);

# %%
flatui = ["#8d99ae", "#2b2d42", 'salmon']
sns.set_palette(flatui)

plt.figure(figsize=(8,6)) 
graph = sns.countplot(x='Churn', data=df, hue='PhoneService', palette=sns.color_palette())

plt.text(-0.17, 600, '7,27%', ha='center', va='center', fontsize=12)
plt.text(0.19, 4760, '66,19%', ha='center', va='center', fontsize=12)
plt.text(0.79, 260, '2,41%', ha='center', va='center', fontsize=12)
plt.text(1.19, 1800, '24,12%', ha='center', va='center', fontsize=12);

# %%
group_c2 = df[['customerID', 'PhoneService', 'Churn']].groupby(['PhoneService', 'Churn'])['customerID'].nunique()
group_c2 = group_c2.reset_index()
group_c2.columns = ['Partner', 'Churn', 'jumlahCustomer']
group_merge_c2 = group_c2
group_merge_c2['Persentase'] = round((group_merge_c2['jumlahCustomer']/7043*100), 2)
group_merge_c2
# Out:
#   Partner Churn  jumlahCustomer  Persentase
# 0      No    No             512        7.27
# 1      No   Yes             170        2.41
# 2     Yes    No            4662       66.19
# 3     Yes   Yes            1699       24.12

# %% [markdown]
# The churn rate for phone service is low, while customers who have a lot of churn are customers who use phone service, this is in line with the number of phone service subscribers who are more (6361) than those who do not subscribe (682)

# %%
df['InternetService'].value_counts()
# Out:
# Fiber optic    2621
# DSL            2092
# No             1321
# unknown        1009
# Name: InternetService, dtype: int64

# %%
flatui = ["#8d99ae", "#2b2d42", 'salmon', '#c9ada7']
sns.set_palette(flatui)

plt.figure(figsize=(6,4)) 
graph = sns.countplot(x='InternetService', data=df,palette=sns.color_palette())

plt.text(0, 1100, '14,33%', ha='center', va='center', fontsize=10)
plt.text(1, 1400, '18,76%', ha='center', va='center', fontsize=10)
plt.text(2, 2160, '29,70%', ha='center', va='center', fontsize=10)
plt.text(3, 2680, '37,21%', ha='center', va='center', fontsize=10);

# %%
flatui = ["#8d99ae", "#2b2d42", 'salmon', '#c9ada7']
sns.set_palette(flatui)

plt.figure(figsize=(8,6)) 
graph = sns.countplot(x='Churn', data=df, hue='InternetService', palette=sns.color_palette())

plt.text(-0.3, 790, '10,62%', ha='center', va='center', fontsize=12)
plt.text(-0.1, 1260, '17,36%', ha='center', va='center', fontsize=12)
plt.text(0.1, 1720, '24,01%', ha='center', va='center', fontsize=12)
plt.text(0.3, 1550, '21,47%', ha='center', va='center', fontsize=12)
plt.text(0.7, 300, '3,71%', ha='center', va='center', fontsize=12)
plt.text(0.9, 140, '1,39%', ha='center', va='center', fontsize=12)
plt.text(1.1, 440, '5,69%', ha='center', va='center', fontsize=12)
plt.text(1.3, 1150, '15,75%', ha='center', va='center', fontsize=12);

# %%
group_d = df[['customerID', 'InternetService', 'Churn']].groupby(['InternetService', 'Churn'])['customerID'].nunique()
group_d = group_d.reset_index()
group_d.columns = ['InternetService', 'Churn', 'jumlahCustomer']
group_merge_d = group_d
group_merge_d['Persentase'] = round((group_merge_d['jumlahCustomer']/7043*100), 2)
group_merge_d
# Out:
#   InternetService Churn  jumlahCustomer  Persentase
# 0             DSL    No            1691       24.01
# 1             DSL   Yes             401        5.69
# 2     Fiber optic    No            1512       21.47
# 3     Fiber optic   Yes            1109       15.75
# 4              No    No            1223       17.36
# 5              No   Yes              98        1.39
# 6         unknown    No             748       10.62
# 7         unknown   Yes             261        3.71

# %% [markdown]
# Not only being the highest at 24.01%, but DSL also has a much lower percentage in influencing customer churn than Fiber Optic, which is a difference of 10%. This shows that DSL InternetService is still superior for customer use.
#
# From this we know that most customers who enjoy the service use Fiber Optic internet services, and the second is DSL. However, the number of customers who churn more is using Fiber Optic internet services. Companies can improve or maintain Fiber Optic-based services, so that customers can continue to survive or add new customers.

# %%
df['OnlineSecurity'].value_counts()
# Out:
# No                     2993
# Yes                    1720
# No internet service    1321
# unknown                1009
# Name: OnlineSecurity, dtype: int64

# %%
flatui = ["#8d99ae", "#2b2d42", 'salmon', '#c9ada7']
sns.set_palette(flatui)

plt.figure(figsize=(6,4)) 
graph = sns.countplot(x='OnlineSecurity', data=df,palette=sns.color_palette())

plt.text(0, 1100, '14,33%', ha='center', va='center', fontsize=10)
plt.text(1, 1410, '18,76%', ha='center', va='center', fontsize=10)
plt.text(2, 1800, '24,42%', ha='center', va='center', fontsize=10)
plt.text(3, 3060, '42,45%', ha='center', va='center', fontsize=10);

# %%
flatui = ["#8d99ae", "#2b2d42", 'salmon', '#c9ada7']
sns.set_palette(flatui)

plt.figure(figsize=(8,6)) 
graph = sns.countplot(x='Churn', data=df, hue='OnlineSecurity', palette=sns.color_palette())

plt.text(-0.3, 790, '10,62%', ha='center', va='center', fontsize=12)
plt.text(-0.1, 1270, '17,36%', ha='center', va='center', fontsize=12)
plt.text(0.1, 1500, '20,86%', ha='center', va='center', fontsize=12) 
plt.text(0.3, 1770, '24,62%', ha='center', va='center', fontsize=12)
plt.text(0.7, 300, '5,69%', ha='center', va='center', fontsize=12)
plt.text(0.9, 140, '1,39%', ha='center', va='center', fontsize=12)
plt.text(1.1, 290, '3,71%', ha='center', va='center', fontsize=12)
plt.text(1.3, 1300, '17,88%', ha='center', va='center', fontsize=12);

# %%
group_d2 = df[['customerID', 'OnlineSecurity', 'Churn']].groupby(['OnlineSecurity', 'Churn'])['customerID'].nunique()
group_d2 = group_d2.reset_index()
group_d2.columns = ['OnlineSecurity', 'Churn', 'jumlahCustomer']
group_merge_d2 = group_d2
group_merge_d2['Persentase'] = round((group_merge_d2['jumlahCustomer']/7043*100), 2)
group_merge_d2
# Out:
#         OnlineSecurity Churn  jumlahCustomer  Persentase
# 0                   No    No            1734       24.62
# 1                   No   Yes            1259       17.88
# 2  No internet service    No            1223       17.36
# 3  No internet service   Yes              98        1.39
# 4                  Yes    No            1469       20.86
# 5                  Yes   Yes             251        3.56
# 6              unknown    No             748       10.62
# 7              unknown   Yes             261        3.71

# %% [markdown]
# From the data above, it is known that most customers do not subscribe to Online Security, followed by 1720 customers who subscribe to Online Security, 1321 customers who do not have internet service, and 1009 unknown customers. The churn rate in Online Security is dominated by customers who do not churn, while customers who churn are dominated by customers who do not use Online Security services.

# %%
df['OnlineBackup'].value_counts()
# Out:
# No                     2643
# Yes                    2070
# No internet service    1321
# unknown                1009
# Name: OnlineBackup, dtype: int64

# %%
flatui = ["#8d99ae", "#2b2d42", 'salmon', '#c9ada7']
sns.set_palette(flatui)

plt.figure(figsize=(6,4)) 
graph = sns.countplot(x='OnlineBackup', data=df,palette=sns.color_palette())

plt.text(0, 1100, '14,33%', ha='center', va='center', fontsize=10)
plt.text(1, 1410, '18,75%', ha='center', va='center', fontsize=10)
plt.text(3, 2130, '29,39%', ha='center', va='center', fontsize=10)
plt.text(2, 2700, '37,53%', ha='center', va='center', fontsize=10);

# %%
flatui = ["#8d99ae", "#2b2d42", 'salmon', '#c9ada7']
sns.set_palette(flatui)

plt.figure(figsize=(8,6)) 
graph = sns.countplot(x='Churn', data=df, hue='OnlineBackup', palette=sns.color_palette())

plt.text(-0.3, 790, '10,62%', ha='center', va='center', fontsize=12)
plt.text(-0.1, 1270, '17,36%', ha='center', va='center', fontsize=12)
plt.text(0.1, 1610, '22,38%', ha='center', va='center', fontsize=12) 
plt.text(0.3, 1660, '23,10%', ha='center', va='center', fontsize=12)
plt.text(0.7, 300, '3,71%', ha='center', va='center', fontsize=12)
plt.text(0.9, 140, '1,39%', ha='center', va='center', fontsize=12)
plt.text(1.1, 1100, '15,15%', ha='center', va='center', fontsize=12)
plt.text(1.3, 480, '6,29%', ha='center', va='center', fontsize=12);

# %%
group_e = df[['customerID', 'OnlineBackup', 'Churn']].groupby(['OnlineBackup', 'Churn'])['customerID'].nunique()
group_e = group_e.reset_index()
group_e.columns = ['OnlineBackup', 'Churn', 'jumlahCustomer']
group_merge_e = group_e
group_merge_e['Persentase'] = round((group_merge_e['jumlahCustomer']/7043*100), 2)
group_merge_e
# Out:
#           OnlineBackup Churn  jumlahCustomer  Persentase
# 0                   No    No            1576       22.38
# 1                   No   Yes            1067       15.15
# 2  No internet service    No            1223       17.36
# 3  No internet service   Yes              98        1.39
# 4                  Yes    No            1627       23.10
# 5                  Yes   Yes             443        6.29
# 6              unknown    No             748       10.62
# 7              unknown   Yes             261        3.71

# %% [markdown]
# From the data above, it is known that most customers do not subscribe to Online Backup, followed by 2070 customers who do not subscribe to Online Backup, 1321 customers who do not have internet service, and 1009 unknown customers. The churn rate in Online Backup is dominated by customers who do not have internet service. do not churn, while customers who churn are dominated by customers who do not use Online Backup services.

# %%
df['DeviceProtection'].value_counts()
# Out:
# No                     2643
# Yes                    2070
# No internet service    1321
# unknown                1009
# Name: DeviceProtection, dtype: int64

# %%
flatui = ["#8d99ae", "#2b2d42", 'salmon', '#c9ada7']
sns.set_palette(flatui)

plt.figure(figsize=(6,4)) 
graph = sns.countplot(x='DeviceProtection', data=df,palette=sns.color_palette())

plt.text(0, 1100, '14,33%', ha='center', va='center', fontsize=10)
plt.text(1, 1410, '18,75%', ha='center', va='center', fontsize=10)
plt.text(3, 2130, '29,39%', ha='center', va='center', fontsize=10)
plt.text(2, 2700, '37,53%', ha='center', va='center', fontsize=10);

# %%
flatui = ["#8d99ae", "#2b2d42", 'salmon', '#c9ada7']
sns.set_palette(flatui)

plt.figure(figsize=(8,6)) 
graph = sns.countplot(x='Churn', data=df, hue='DeviceProtection', palette=sns.color_palette())

plt.text(-0.3, 790, '10,62%', ha='center', va='center', fontsize=12)
plt.text(-0.1, 1260, '17,36%', ha='center', va='center', fontsize=12)
plt.text(0.1, 1630, '22,72%', ha='center', va='center', fontsize=12) 
plt.text(0.3, 1640, '22,76%', ha='center', va='center', fontsize=12)
plt.text(0.7, 300, '3,71%', ha='center', va='center', fontsize=12)
plt.text(0.9, 140, '1,39%', ha='center', va='center', fontsize=12)
plt.text(1.1, 1080, '14,81%', ha='center', va='center', fontsize=12)
plt.text(1.3, 500, '6,63%', ha='center', va='center', fontsize=12);

# %%
group_f = df[['customerID', 'DeviceProtection', 'Churn']].groupby(['DeviceProtection', 'Churn'])['customerID'].nunique()
group_f = group_f.reset_index()
group_f.columns = ['DeviceProtection', 'Churn', 'jumlahCustomer']
group_merge_f = group_f
group_merge_f['Persentase'] = round((group_merge_f['jumlahCustomer']/7043*100), 2)
group_merge_f
# Out:
#       DeviceProtection Churn  jumlahCustomer  Persentase
# 0                   No    No            1600       22.72
# 1                   No   Yes            1043       14.81
# 2  No internet service    No            1223       17.36
# 3  No internet service   Yes              98        1.39
# 4                  Yes    No            1603       22.76
# 5                  Yes   Yes             467        6.63
# 6              unknown    No             748       10.62
# 7              unknown   Yes             261        3.71

# %% [markdown]
# From the data above, it is known that most customers do not subscribe to Device Protection, followed by 2070 customers who do not subscribe to Device Protection, 1321 customers who do not have internet service, and 1009 unknown customers. The churn rate in Device Protection is dominated by customers who do not have internet service. do not churn, while customers who churn are dominated by customers who do not use Device Protection services.

# %%
df['TechSupport'].value_counts()
# Out:
# No                     2973
# Yes                    1740
# No internet service    1321
# unknown                1009
# Name: TechSupport, dtype: int64

# %%
flatui = ["#8d99ae", "#2b2d42", 'salmon', '#c9ada7']
sns.set_palette(flatui)

plt.figure(figsize=(6,4)) 
graph = sns.countplot(x='TechSupport', data=df,palette=sns.color_palette())

plt.text(0, 1100, '14,33%', ha='center', va='center', fontsize=10)
plt.text(1, 1410, '18,75%', ha='center', va='center', fontsize=10)
plt.text(2, 3040, '42,21%', ha='center', va='center', fontsize=10)
plt.text(3, 1840, '24,71%', ha='center', va='center', fontsize=10);

# %%
flatui = ["#8d99ae", "#2b2d42", 'salmon', '#c9ada7']
sns.set_palette(flatui)

plt.figure(figsize=(8,6)) 
graph = sns.countplot(x='Churn', data=df, hue='TechSupport', palette=sns.color_palette())

plt.text(-0.3, 790, '10,62%', ha='center', va='center', fontsize=12)
plt.text(-0.1, 1260, '17,36%', ha='center', va='center', fontsize=12)
plt.text(0.1, 1775, '24,68%', ha='center', va='center', fontsize=12) 
plt.text(0.3, 1510, '20,80%', ha='center', va='center', fontsize=12)
plt.text(0.7, 300, '3,71%', ha='center', va='center', fontsize=12)
plt.text(0.9, 140, '1,39%', ha='center', va='center', fontsize=12)
plt.text(1.1, 1275, '17,54%', ha='center', va='center', fontsize=12)
plt.text(1.3, 305, '3,90%', ha='center', va='center', fontsize=12);

# %%
group_g = df[['customerID', 'TechSupport', 'Churn']].groupby(['TechSupport', 'Churn'])['customerID'].nunique()
group_g = group_g.reset_index()
group_g.columns = ['TechSupport', 'Churn', 'jumlahCustomer']
group_merge_g = group_g
group_merge_g['Persentase'] = round((group_merge_g['jumlahCustomer']/7043*100), 2)
group_merge_g
# Out:
#            TechSupport Churn  jumlahCustomer  Persentase
# 0                   No    No            1738       24.68
# 1                   No   Yes            1235       17.54
# 2  No internet service    No            1223       17.36
# 3  No internet service   Yes              98        1.39
# 4                  Yes    No            1465       20.80
# 5                  Yes   Yes             275        3.90
# 6              unknown    No             748       10.62
# 7              unknown   Yes             261        3.71

# %% [markdown]
# From the data above, it is known that most customers do not subscribe to Tech Support, followed by 1740 customers who subscribe to Tech Support, 1321 customers who do not have internet service, and 1009 unknown customers. The churn rate in Tech Support is dominated by customers who do not churn, while customers who churn are dominated by customers who do not use Tech Support services.

# %%
df['StreamingTV'].value_counts()
# Out:
# No                     2403
# Yes                    2310
# No internet service    1321
# unknown                1009
# Name: StreamingTV, dtype: int64

# %%
flatui = ["#8d99ae", "#2b2d42", 'salmon', '#c9ada7']
sns.set_palette(flatui)

plt.figure(figsize=(6,4)) 
graph = sns.countplot(x='StreamingTV', data=df,palette=sns.color_palette())

plt.text(0, 1100, '14,33%', ha='center', va='center', fontsize=10)
plt.text(1, 1410, '18,76%', ha='center', va='center', fontsize=10)
plt.text(2, 2450, '34,11%', ha='center', va='center', fontsize=10)
plt.text(3, 2400, '32,80%', ha='center', va='center', fontsize=10);

# %%
flatui = ["#8d99ae", "#2b2d42", 'salmon', '#c9ada7']
sns.set_palette(flatui)

plt.figure(figsize=(8,6)) 
graph = sns.countplot(x='Churn', data=df, hue='StreamingTV', palette=sns.color_palette())

plt.text(-0.3, 790, '10,62%', ha='center', va='center', fontsize=12)
plt.text(-0.1, 1260, '17,36%', ha='center', va='center', fontsize=12)
plt.text(0.1, 1640, '22,73%', ha='center', va='center', fontsize=12) 
plt.text(0.3, 1642, '22,75%', ha='center', va='center', fontsize=12)
plt.text(0.7, 300, '3,71%', ha='center', va='center', fontsize=12)
plt.text(0.9, 140, '1,39%', ha='center', va='center', fontsize=12)
plt.text(1.1, 845, '11,39%', ha='center', va='center', fontsize=12)
plt.text(1.3, 745, '10,05%', ha='center', va='center', fontsize=12);

# %%
group_h = df[['customerID', 'StreamingTV', 'Churn']].groupby(['StreamingTV', 'Churn'])['customerID'].nunique()
group_h = group_h.reset_index()
group_h.columns = ['StreamingTV', 'Churn', 'jumlahCustomer']
group_merge_h = group_h
group_merge_h['Persentase'] = round((group_merge_h['jumlahCustomer']/7043*100), 2)
group_merge_h
# Out:
#            StreamingTV Churn  jumlahCustomer  Persentase
# 0                   No    No            1601       22.73
# 1                   No   Yes             802       11.39
# 2  No internet service    No            1223       17.36
# 3  No internet service   Yes              98        1.39
# 4                  Yes    No            1602       22.75
# 5                  Yes   Yes             708       10.05
# 6              unknown    No             748       10.62
# 7              unknown   Yes             261        3.71

# %% [markdown]
# From the data above, it is known that most customers do not subscribe to Streaming TV, followed by customers who subscribe to 2310 customers, 1321 customers who do not have internet service, and 1009 unknown customers. The churn rate on Streaming TV is dominated by customers who do not churn, while subscribers who churn are not much different between those who subscribe and do not subscribe to Streaming TV

# %%
df['StreamingMovies'].value_counts()
# Out:
# No                     2394
# Yes                    2319
# No internet service    1321
# unknown                1009
# Name: StreamingMovies, dtype: int64

# %%
flatui = ["#8d99ae", "#2b2d42", 'salmon', '#c9ada7']
sns.set_palette(flatui)

plt.figure(figsize=(6,4)) 
graph = sns.countplot(x='StreamingMovies', data=df,palette=sns.color_palette())

plt.text(0, 1100, '14,33%', ha='center', va='center', fontsize=10)
plt.text(1, 1410, '18,75%', ha='center', va='center', fontsize=10)
plt.text(2, 2450, '32,93%', ha='center', va='center', fontsize=10)
plt.text(3, 2400, '33,99%', ha='center', va='center', fontsize=10);

# %%
flatui = ["#8d99ae", "#2b2d42", 'salmon', '#c9ada7']
sns.set_palette(flatui)

plt.figure(figsize=(8,6)) 
graph = sns.countplot(x='Churn', data=df, hue='StreamingMovies', palette=sns.color_palette())

plt.text(-0.3, 790, '10,62%', ha='center', va='center', fontsize=12)
plt.text(-0.1, 1260, '17,36%', ha='center', va='center', fontsize=12)
plt.text(0.1, 1620, '22,45%', ha='center', va='center', fontsize=12) 
plt.text(0.3, 1655, '23,03%', ha='center', va='center', fontsize=12)
plt.text(0.7, 300, '3,71%', ha='center', va='center', fontsize=12)
plt.text(0.9, 140, '1,39%', ha='center', va='center', fontsize=12)
plt.text(1.1, 845, '11,54%', ha='center', va='center', fontsize=12)
plt.text(1.3, 740, '9,90%', ha='center', va='center', fontsize=12);

# %%
group_i = df[['customerID', 'StreamingMovies', 'Churn']].groupby(['StreamingMovies', 'Churn'])['customerID'].nunique()
group_i = group_i.reset_index()
group_i.columns = ['StreamingMovies', 'Churn', 'jumlahCustomer']
group_merge_i = group_i
group_merge_i['Persentase'] = round((group_merge_i['jumlahCustomer']/7043*100), 2)
group_merge_i
# Out:
#        StreamingMovies Churn  jumlahCustomer  Persentase
# 0                   No    No            1581       22.45
# 1                   No   Yes             813       11.54
# 2  No internet service    No            1223       17.36
# 3  No internet service   Yes              98        1.39
# 4                  Yes    No            1622       23.03
# 5                  Yes   Yes             697        9.90
# 6              unknown    No             748       10.62
# 7              unknown   Yes             261        3.71

# %% [markdown]
# From the data above, it is known that most customers do not subscribe to Streaming Movies, followed by 2319 subscribers, 1321 customers who do not have internet service, and 1009 unknown customers. The churn rate for Streaming Movies is dominated by customers who do not churn, while subscribers who churn are not much different between those who subscribe and do not subscribe to Streaming Movies

# %% [markdown]
# From all the data services above, it shows that the services provided are still not superior that can be utilized by the company because there are still many customers who continue to subscribe even though they do not use the services provided by the company.

# %%
df['PaymentMethod'].value_counts()
# Out:
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

# %%
flatui = ["#8d99ae", "#2b2d42", 'salmon', '#c9ada7']
sns.set_palette(flatui)

plt.figure(figsize=(6,4)) 
graph = sns.countplot(x='PaymentMethod', data=df,palette=sns.color_palette())

plt.text(0, 2410, '33,58%', ha='center', va='center', fontsize=10)
plt.text(1, 1620, '22,89%', ha='center', va='center', fontsize=10)
plt.text(2, 1600, '21,92%', ha='center', va='center', fontsize=10)
plt.text(3, 1600, '21,61%', ha='center', va='center', fontsize=10);

# %%
flatui = ["#8d99ae", "#2b2d42", 'salmon', '#c9ada7']
sns.set_palette(flatui)

plt.figure(figsize=(8,6)) 
graph = sns.countplot(x='Churn', data=df, hue='PaymentMethod', palette=sns.color_palette())

plt.text(-0.3, 1320, '18,37%', ha='center', va='center', fontsize=12)
plt.text(-0.1, 1330, '18,51%', ha='center', va='center', fontsize=12)
plt.text(0.1, 1310, '18,26%', ha='center', va='center', fontsize=12) 
plt.text(0.3, 1310, '18,32%', ha='center', va='center', fontsize=12)
plt.text(0.7, 1100, '15,21%', ha='center', va='center', fontsize=12)
plt.text(0.9, 340, '4,37%', ha='center', va='center', fontsize=12)
plt.text(1.1, 290, '3,66%', ha='center', va='center', fontsize=12)
plt.text(1.3, 270, '3,29%', ha='center', va='center', fontsize=12);

# %%
group_j = df[['customerID', 'PaymentMethod', 'Churn']].groupby(['PaymentMethod', 'Churn'])['customerID'].nunique()
group_j = group_j.reset_index()
group_j.columns = ['PaymentMethod', 'Churn', 'jumlahCustomer']
group_merge_j = group_j
group_merge_j['Persentase'] = round((group_merge_j['jumlahCustomer']/7043*100), 2)
group_merge_j
# Out:
#                PaymentMethod Churn  jumlahCustomer  Persentase
# 0  Bank transfer (automatic)    No            1286       18.26
# 1  Bank transfer (automatic)   Yes             258        3.66
# 2    Credit card (automatic)    No            1290       18.32
# 3    Credit card (automatic)   Yes             232        3.29
# 4           Electronic check    No            1294       18.37
# 5           Electronic check   Yes            1071       15.21
# 6               Mailed check    No            1304       18.51
# 7               Mailed check   Yes             308        4.37

# %% [markdown]
# From the data above, it is known that most customers use Electronic Check for the Payment Method, the churn rate in the Payment Method is dominated by customers who do not churn, while customers who churn are dominated by customers who use Electronic check for the payment method.

# %%
plt.figure(figsize = (8,6))
sns.heatmap(df.corr(), annot=True);

# %% [markdown]
# - TotalChargers and tenure is multicolinearitas
# - TotalChargers and MonthlyCharges is multicolinearitas
#
# one of multicolinearity column need to be dropped down

# %% [markdown]
# ## Feature Engineering

# %%
# Print Value count

col = ['customerID', 'tenure', 'MonthlyCharges', 'TotalCharges', 'SeniorCitizen', 
       'Partner', 'gender', 'Dependents', 'PhoneService', 'MultipleLines', 
       'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
       'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
       'PaperlessBilling', 'PaymentMethod']
for i in range(0, len(col)):
    a = i+1
    a = df[col[i]].value_counts()
    print('Value count', col[i], ':\n', a, '\n')
# Out:
# Value count customerID :
#  7590-VHVEG    1
# 3791-LGQCY    1
# 6008-NAIXK    1
# 5956-YHHRX    1
# 5365-LLFYV    1
#              ..
# 9796-MVYXX    1
# 2637-FKFSY    1
# 1552-AAGRX    1
# 4304-TSPVK    1
# 3186-AJIEK    1
# Name: customerID, Length: 7043, dtype: int64
#
# Value count tenure :
#  1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: tenure, Length: 73, dtype: int64
#
# Value count MonthlyCharges :
#  20.05     61
# 19.85     45
# 19.95     44
# 19.90     44
# 20.00     43
#           ..
# 23.65      1
# 114.70     1
# 43.65      1
# 87.80      1
# 78.70      1
# Name: MonthlyCharges, Length: 1585, dtype: int64
#
# Value count TotalCharges :
#  20.20      11
# 19.75       9
# 20.05       8
# 19.90       8
# 19.65       8
#            ..
# 6849.40     1
# 692.35      1
# 130.15      1
# 3211.90     1
# 6844.50     1
# Name: TotalCharges, Length: 6530, dtype: int64
#
# ...

# %%
# One Hot Encoding (Categorical)

col_encod1 = ['SeniorCitizen', 'gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 
             'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 
             'TechSupport', 'StreamingTV', 'StreamingMovies', 'PaperlessBilling', 'PaymentMethod']

result = pd.DataFrame()
for i in range(0, len(col_encod1)):
    a = i+1
    a = pd.get_dummies(df[col_encod1[i]], prefix=col_encod1[i], drop_first = False)
    df.drop(col_encod1[i], axis=1, inplace=True)
    result = pd.concat([result, a], axis=1)
    
result
# Out:
#       SeniorCitizen_0.0  SeniorCitizen_1.0  SeniorCitizen_unknown  \
# 0                     0                  0                      1
# 1                     0                  0                      1
# 2                     0                  0                      1
# 3                     0                  0                      1
# 4                     0                  0                      1
# ...                 ...                ...                    ...
# 7038                  1                  0                      0
# 7039                  1                  0                      0
# 7040                  1                  0                      0
# 7041                  0                  1                      0
# 7042                  1                  0                      0
#
#       gender_Female  gender_Male  gender_unknown  Partner_No  Partner_Yes  \
# 0                 0            0               1           0            0
# ...

# %%
df = pd.concat([df, result], axis = 1)
df
# Out:
#       customerID  tenure        Contract  MonthlyCharges  TotalCharges Churn  \
# 0     7590-VHVEG       1  Month-to-month           29.85         29.85    No
# 1     5575-GNVDE      34        One year           56.95       1889.50    No
# 2     3668-QPYBK       2  Month-to-month           53.85        108.15   Yes
# 3     7795-CFOCW      45        One year           42.30       1840.75    No
# 4     9237-HQITU       2  Month-to-month           70.70        151.65   Yes
# ...          ...     ...             ...             ...           ...   ...
# 7038  6840-RESVB      24        One year           84.80       1990.50    No
# 7039  2234-XADUH      72        One year          103.20       7362.90    No
# 7040  4801-JZAZL      11  Month-to-month           29.60        346.45    No
# 7041  8361-LTMKD       4  Month-to-month           74.40        306.60   Yes
# 7042  3186-AJIEK      66        Two year          105.65       6844.50    No
#
# ...

# %%
# Encoding MAP 2 (Ordinal)

df['Contract']= df['Contract'].map({"Month-to-month":0, "One year":1, "Two year":2})

# %%
# Standard Scaler

scaler = StandardScaler()
df[['tenure']] = scaler.fit_transform(df[['tenure']])
df[['MonthlyCharges']] = scaler.fit_transform(df[['MonthlyCharges']])
df.head()
# Out:
#    customerID    tenure  Contract  MonthlyCharges  TotalCharges Churn  \
# 0  7590-VHVEG -1.277445         0       -1.160323         29.85    No
# 1  5575-GNVDE  0.066327         1       -0.259629       1889.50    No
# 2  3668-QPYBK -1.236724         0       -0.362660        108.15   Yes
# 3  7795-CFOCW  0.514251         1       -0.746535       1840.75    No
# 4  9237-HQITU -1.236724         0        0.197365        151.65   Yes
#
#    SeniorCitizen_0.0  SeniorCitizen_1.0  SeniorCitizen_unknown  gender_Female  \
# 0                  0                  0                      1              0
# 1                  0                  0                      1              0
# 2                  0                  0                      1              0
# 3                  0                  0                      1              0
# 4                  0                  0                      1              0
#
#    ...  StreamingMovies_No  StreamingMovies_No internet service  \
# ...

# %% [markdown]
# ## Preprocessing Modeling

# %%
# Feature Selection

df.drop('customerID', axis=1, inplace=True) #multicolinear
df.drop('TotalCharges', axis=1, inplace=True)#identifier

# %%
# Encoding Data Target

# Churn

df['Churn'].replace('Yes', 1, inplace = True)
df['Churn'].replace('No', 0, inplace = True)

# %%
df
# Out:
#         tenure  Contract  MonthlyCharges  Churn  SeniorCitizen_0.0  \
# 0    -1.277445         0       -1.160323      0                  0
# 1     0.066327         1       -0.259629      0                  0
# 2    -1.236724         0       -0.362660      1                  0
# 3     0.514251         1       -0.746535      0                  0
# 4    -1.236724         0        0.197365      1                  0
# ...        ...       ...             ...    ...                ...
# 7038 -0.340876         1        0.665992      0                  1
# 7039  1.613701         1        1.277533      0                  1
# 7040 -0.870241         0       -1.168632      0                  1
# 7041 -1.155283         0        0.320338      1                  0
# 7042  1.369379         2        1.358961      0                  1
#
#       SeniorCitizen_1.0  SeniorCitizen_unknown  gender_Female  gender_Male  \
# 0                     0                      1              0            0
# ...

# %% [markdown]
# ## Modeling

# %%
X = df.drop(['Churn'], axis=1)
y = df['Churn']

# %%
model = ExtraTreesClassifier()
model.fit(X,y)

feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(23).plot(kind = 'barh', color='salmon')
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=42)

# %%
X_train
# Out:
#         tenure  Contract  MonthlyCharges  SeniorCitizen_0.0  \
# 2142 -0.463037         1        0.002935                  1
# 1623  0.880735         2        1.078118                  1
# 6074 -1.277445         0       -1.373033                  1
# 1362 -1.155283         0        0.180747                  1
# 6754 -1.318165         2       -0.095111                  1
# ...        ...       ...             ...                ...
# 3772 -1.277445         0        1.004999                  1
# 5191 -0.381597         2        0.875378                  1
# 5226 -0.829521         0       -1.449476                  1
# 5390 -0.829521         0        1.152899                  0
# 860  -0.259435         1       -1.494344                  0
#
#       SeniorCitizen_1.0  SeniorCitizen_unknown  gender_Female  gender_Male  \
# 2142                  0                      0              1            0
# 1623                  0                      0              1            0
# ...

# %% [markdown]
# Handling Imbalance Data

# %%
print(pd.Series(y_train).value_counts())
# Out:
# 0    4138
# 1    1496
# Name: Churn, dtype: int64

# %%
x_under, y_under = under_sampling.RandomUnderSampler(1).fit_resample(X_train, y_train)
#x_over, y_over = over_sampling.RandomOverSampler(1).fit_resample(X_train, y_train)

# %%
print(pd.Series(y_under).value_counts())
# Out:
# 0    1496
# 1    1496
# Name: Churn, dtype: int64

# %%
X_train = x_under
y_train = y_under

# %% [markdown]
# ## Modeling

# %%
# Modeling

from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([1, 0, 0, ..., 0, 0, 1])

# %% [markdown]
# ## Model Evaluation

# %%
cm_model = confusion_matrix(y_test, y_pred)

labels = ['not_churn', 'churn']

print(classification_report(y_test, y_pred, target_names = labels))
f, ax = plt.subplots(figsize=(8,5))
sns.heatmap(cm_model, annot=True, fmt=".0f", ax=ax, cmap = 'pink')

ax.xaxis.set_ticklabels(labels)
ax.yaxis.set_ticklabels(labels)

plt.title('Logistic Regression TRAIN 80%')
plt.xlabel('PREDICTED')
plt.ylabel('ACTUAL')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#    not_churn       0.92      0.73      0.82      1036
#        churn       0.53      0.83      0.64       373
#
#     accuracy                           0.76      1409
#    macro avg       0.72      0.78      0.73      1409
# weighted avg       0.82      0.76      0.77      1409

# %% [markdown]
# ## Overfitting and Underfitting

# %%
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

# %%
print(accuracy_score(y_train, y_pred_train))
# Out:
# 0.7520053475935828

# %%
print(accuracy_score(y_test, y_pred_test))
# Out:
# 0.758694109297374

# %% [markdown]
# ## AUC ROC

# %%
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)
y_proba_train = model.predict_proba(X_train)[:,1]
y_proba_test = model.predict_proba(X_test)[:,1]
cm_train = confusion_matrix(y_train,y_pred_train)
cm_test = confusion_matrix(y_test,y_pred_test)

# %%
fpr_train, tpr_train, threshold_train = roc_curve(y_train, y_proba_train)
roc_auc_train = auc(fpr_train, tpr_train)
fpr_test, tpr_test, threshold_test = roc_curve(y_test, y_proba_test)
roc_auc_test = auc(fpr_test, tpr_test)

# %%
# True Positive
tp_train, tp_test = cm_train[1][1], cm_test[1][1]
# True Negative
tn_train, tn_test = cm_train[0][0], cm_test[0][0]
# False Positive
fp_train, fp_test = cm_train[1][0], cm_test[1][0]
# False Negative
fn_train, fn_test = cm_train[0][1], cm_test[0][1]

# %%
# Overall, how often is the classifier correct?
accuracy_train, accuracy_test = ((tp_train + tn_train) / (tp_train + tn_train + fp_train + fn_train)), (
            (tp_test + tn_test) / (tp_test + tn_test + fp_test + fn_test))
# When it's actually yes, how often does it predict yes?
recall_train, recall_test = (tp_train / (tp_train + fp_train)), (tp_test / (tp_test + fp_test))
# When it's actually no, how often does it predict no?
specificity_train, specificity_test = (tn_train / (tn_train + fn_train)), (tn_test / (tn_test + fn_test))
# When it predicts yes, how often is it correct?
precision_train, precision_test = (tp_train / (tp_train + fn_train)), (tp_test / (tp_test + fn_test))
# F1 Score
f1_score_train, f1_score_test = (2 * (precision_train * recall_train) / (precision_train + recall_train)), (
            2 * (precision_test * recall_test) / (precision_test + recall_test))

# %%
# Print all the evaluation metrics
print('\nTrain Confusion Matrix')
print(cm_train)
print('Test Confusion Matrix')
print(cm_test)
print('\nArea Under Curve')
print('AUC train & test        : %.2f%%' % (roc_auc_train * 100), '&', '%.2f%%' % (roc_auc_test * 100))
print('\nConfusion Matrix Evaluation')
print('Accuracy train & test   : %.2f%%' % (accuracy_train * 100), '&', '%.2f%%' % (accuracy_test * 100))
print('Recall train & test     : %.2f%%' % (recall_train * 100), '&', '%.2f%%' % (recall_test * 100))
print('Specificity train & test: %.2f%%' % (specificity_train * 100), '&', '%.2f%%' % (specificity_test * 100))
print('Precision train & test  : %.2f%%' % (precision_train * 100), '&', '%.2f%%' % (precision_test * 100))
print('F1 Score train & test   : %.2f%%' % (f1_score_train * 100), '&', '%.2f%%' % (f1_score_test * 100))
print('Log Loss train & test   :', round(log_loss(y_train, y_pred_train), 4), '&',
          round(log_loss(y_test, y_pred_test), 4))
# Out:
# Train Confusion Matrix
# [[1076  420]
#  [ 322 1174]]
# Test Confusion Matrix
# [[761 275]
#  [ 65 308]]
#
# Area Under Curve
# AUC train & test        : 83.74% & 85.94%
#
# Confusion Matrix Evaluation
# Accuracy train & test   : 75.20% & 75.87%
# Recall train & test     : 78.48% & 82.57%
# Specificity train & test: 71.93% & 73.46%
# Precision train & test  : 73.65% & 52.83%
# F1 Score train & test   : 75.99% & 64.44%
# Log Loss train & test   : 8.5655 & 8.3346

# %%
#create plot of ROC_AUC
plt.figure(figsize=(7, 6))
plt.title('Receiver Operating Characteristic')
plt.plot(fpr_train, tpr_train, 'b', label='Train = %0.2f' % roc_auc_train)
plt.plot(fpr_test, tpr_test, 'g', label='Test  = %0.2f' % roc_auc_test)
plt.legend(loc='lower right')
plt.plot([0, 1], [0, 1], 'r--')
plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# ## Cross Validation and Hypertuning Parameter

# %%
model = LogisticRegression()
scores = cross_val_score(model, X_train, y_train, scoring = 'accuracy', cv = 3)
scores
# Out:
# array([0.74749499, 0.73821464, 0.74322969])

# %%
model.get_params()
# Out:
# {'C': 1.0,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 100,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': None,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
parameters = {"penalty": ['l1', 'l2', 'elasticnet', 'none'],
              "solver": ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
              "n_jobs": [None, -1],
              "max_iter": [10, 100, 1000]
             }

# %%
grid = GridSearchCV(estimator = model, param_grid = parameters, cv=3)

# %%
best_model= grid.fit(X_train, y_train)

# %%
best_model.best_params_
# Out:
# {'max_iter': 10, 'n_jobs': None, 'penalty': 'none', 'solver': 'sag'}

# %%
model_new = LogisticRegression(max_iter= 10, n_jobs= None , penalty= 'none' , solver= 'sag')

# %% [markdown]
# ## Building New Model with Best Parameter

# %%
model_new = model_new.fit(X_train, y_train)

# %%
y_pred_new = model_new.predict(X_test)

# %%
cm_model = confusion_matrix(y_test, y_pred_new)

labels = ['not_churn', 'churn']

print(classification_report(y_test, y_pred_new, target_names = labels))
f, ax = plt.subplots(figsize=(8,5))
sns.heatmap(cm_model, annot=True, fmt=".0f", ax=ax, cmap = 'pink')

ax.xaxis.set_ticklabels(labels)
ax.yaxis.set_ticklabels(labels)

plt.title('Logistic Regression TRAIN 80%')
plt.xlabel('PREDICTED')
plt.ylabel('ACTUAL')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#    not_churn       0.93      0.71      0.80      1036
#        churn       0.51      0.84      0.64       373
#
#     accuracy                           0.75      1409
#    macro avg       0.72      0.78      0.72      1409
# weighted avg       0.82      0.75      0.76      1409

# %% [markdown]
# # Result and Recommendation

# %% [markdown]
# ## Result

# %% [markdown]
# - [gender] From 7043 customer there are 5147 customer who remain subscribed or about 73.46% of telco data. and based on the results of EDA gender does not have much effect on customer churn, because the percentage results show the same thing, which is in the range of 31% of the total
# - [Senior Citizen] Based on the senior citizen category, we can see that most telco customers is not a senior citizen in front of the percentage 71.80%
# The level of customer churn of senior citizens is also low, the largest customer churn is from the non-senior citizen class with a percentage of 17%
# - [Dependents] Telco customers mostly do not have dependants with a percentage of 60.17% compared to customers which has a dependent that is equal to 25.50%. Customers who churn based on the most dependents are customers who do not have dependents with a percentage of 18.83%, even so customers who still stick with telco services still quite a lot with a total of 73.47%
# - [Paperless Billing] Telco customers based on paperless billing are the most customers who using paperless billing with a presentation of 59.22%, while customers who do not use paperless billing in the amount of 40.78%
# The customers who churn the most are customers who use paperless billing with a percentage of 19.88%
# - [contract] There are 3 points that concern us in this result:
#
# 1. Only less than 4% of customers churn where they subscribe for 1 year and 2 years, and this explains that there is no fatal cause that makes customers churn.
# 2. There is an increase in the percentage of about 4.82% between 1 year to 2 year subscriptions for customers who do not churn. that means, some loyal customers are still satisfied with the services provided by the company.
# 3. The high number of Month to Month customers who decide to churn is around 23.50%, which means that there are still many early customers who are not interested in the services provided by the company.
#
# - [Partner] Although the percentage of customers who do not churn and do not have partners is still high, namely 29.52%, partners are important things that can affect customer churn or not. It can be seen that there is a significant difference between churn customers who have partners and customers who do not churn without partners, namely 25.14% .
# </br></br>From this we know, that most customers who enjoy the service are customers who do not have a partner. This is in line with the number of customers who churn, where more are customers who do not have partners. Companies can increase promotions on days associated with couples such as Valentine, to increase customers who want to use the company's services.
#
# - [InternetService] Not only being the highest at 24.01%, but DSL also has a much lower percentage in influencing customer churn than Fiber Optic, which is a difference of 10%. This shows that DSL InternetService is still superior for customer use.
#
# - [Online Security] From the data above, it is known that most customers do not subscribe to Online Security, followed by 1720 customers who subscribe to Online Security, 1321 customers who do not have internet service, and 1009 unknown customers. The churn rate in Online Security is dominated by customers who do not churn, while customers who churn are dominated by customers who do not use Online Security services.
#
# - [Online Backup]
# From the data above, it is known that most customers do not subscribe to Online Backup, followed by 2070 customers who do not subscribe to Online Backup, 1321 customers who do not have internet service, and 1009 unknown customers. The churn rate in Online Backup is dominated by customers who do not have internet service. do not churn, while customers who churn are dominated by customers who do not use Online Backup services.
#
# - [Device Protection]
# From the data above, it is known that most customers do not subscribe to Device Protection, followed by 2070 customers who do not subscribe to Device Protection, 1321 customers who do not have internet service, and 1009 unknown customers. The churn rate in Device Protection is dominated by customers who do not have internet service. do not churn, while customers who churn are dominated by customers who do not use Device Protection services.
#
# - [Tech Support]
# From the data above, it is known that most customers do not subscribe to Tech Support, followed by 1740 customers who subscribe to Tech Support, 1321 customers who do not have internet service, and 1009 unknown customers. The churn rate in Tech Support is dominated by customers who do not churn, while customers who churn are dominated by customers who do not use Tech Support services.
#
# - [Streaming TV]
# From the data above, it is known that most customers do not subscribe to Streaming TV, followed by customers who subscribe to 2310 customers, 1321 customers who do not have internet service, and 1009 unknown customers. The churn rate on Streaming TV is dominated by customers who do not churn, while subscribers who churn are not much different between those who subscribe and do not subscribe to Streaming TV
#
# - [Streaming Movie]
# From the data above, it is known that most customers do not subscribe to Streaming Movies, followed by 2319 subscribers, 1321 customers who do not have internet service, and 1009 unknown customers. The churn rate for Streaming Movies is dominated by customers who do not churn, while subscribers who churn are not much different between those who subscribe and do not subscribe to Streaming Movies
#
# - [Phone Service]
# The churn rate for phone service is low, while customers who have a lot of churn are customers who use phone service, this is in line with the number of phone service subscribers who are more (90.6%) than those who do not subscribe (9.4%)
#
# - [All services] From all the data services above, it shows that the services provided are still not superior that can be utilized by the company because there are still many customers who continue to subscribe even though they do not use the services provided by the company.
#
# -  From the modeling, we get 75% churn accuracy, 51% Precision churn, 84% Recall churn, and 64% F1 Score churn. In this case modeling, it is better to see someone who does not churn into churn so it is better to use recall as an indication of model performance.
#
# - To see further performance of the model, a probability check was carried out with ROC-AUC, it was found that the difference in accuracy between the train data and the test data was less than 0.05, so it can be concluded that the model made is good.
#
# - when parameter adjustment is made with hyperparameter tuning, there is not much change in accuracy

# %% [markdown]
# ## Recommendation

# %% [markdown]
# *   Recommendation for "Churn" Customer : </br>Focus on promotion, campaign or give advantage for return old customer such as discount reactivation or free services. Make on point reactivation strategy, give big advantage to old customer who already churn
# *   Recommendation for "Not Churn" Customer : </br>  Focus on strategy to raise income such as down selling such as bundle for a few product
